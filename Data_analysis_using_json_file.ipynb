# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
df1=pd.read_json('https://raw.githubusercontent.com/ozlerhakan/mongodb-json-files/master/datasets/books.json',lines=True)

# %%
df1
# Out:
#                                       _id  \
# 0                                       1
# 1                                       2
# 2                                       3
# 3                                       4
# 4                                       5
# ..                                    ...
# 426  {'$oid': '53c2ae8528d75d572c06adb8'}
# 427  {'$oid': '53c2ae8528d75d572c06adb9'}
# 428  {'$oid': '53c2ae8528d75d572c06adba'}
# 429  {'$oid': '53c2ae8528d75d572c06adbb'}
# 430  {'$oid': '53c2ae8528d75d572c06adbc'}
#
#                                          title           isbn  pageCount  \
# 0                            Unlocking Android     1933988673        416
# 1            Android in Action, Second Edition     1935182722        592
# 2                     Specification by Example     1617290084          0
# 3                             Flex 3 in Action     1933988746        576
# 4                             Flex 4 in Action     1935182420        600
# ...

# %% [markdown]
# # Data exploration

# %%
df1.head()
# Out:
#   _id                              title        isbn  pageCount  \
# 0   1                  Unlocking Android  1933988673        416
# 1   2  Android in Action, Second Edition  1935182722        592
# 2   3           Specification by Example  1617290084          0
# 3   4                   Flex 3 in Action  1933988746        576
# 4   5                   Flex 4 in Action  1935182420        600
#
#                                publishedDate  \
# 0  {'$date': '2009-04-01T00:00:00.000-0700'}
# 1  {'$date': '2011-01-14T00:00:00.000-0800'}
# 2  {'$date': '2011-06-03T00:00:00.000-0700'}
# 3  {'$date': '2009-02-02T00:00:00.000-0800'}
# 4  {'$date': '2010-11-15T00:00:00.000-0800'}
#
#                                         thumbnailUrl  \
# 0  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 1  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 2  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 3  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# ...

# %%
df1.columns
# Out:
# Index(['_id', 'title', 'isbn', 'pageCount', 'publishedDate', 'thumbnailUrl',
#        'shortDescription', 'longDescription', 'status', 'authors',
#        'categories'],
#       dtype='object')

# %%
#Total number of columns
df1.shape[1]
# Out:
# 11

# %%
#statistical inormation of DataFrame
df1.describe()
# Out:
#          pageCount
# count   431.000000
# mean    289.259861
# std     260.873349
# min       0.000000
# 25%       0.000000
# 50%     350.000000
# 75%     475.000000
# max    1101.000000

# %%
#Checking NaN values in each column
df1.isnull().sum()
# Out:
# _id                   0
# title                 0
# isbn                  3
# pageCount             0
# publishedDate        78
# thumbnailUrl         20
# shortDescription    271
# longDescription     168
# status                0
# authors               0
# categories            0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431 entries, 0 to 430
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               431 non-null    object
#  1   title             431 non-null    object
#  2   isbn              428 non-null    object
#  3   pageCount         431 non-null    int64
#  4   publishedDate     353 non-null    object
#  5   thumbnailUrl      411 non-null    object
#  6   shortDescription  160 non-null    object
#  7   longDescription   263 non-null    object
#  8   status            431 non-null    object
#  9   authors           431 non-null    object
#  10  categories        431 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 20.3+ KB

# %% [markdown]
# # Data cleaning

# %%
#Cecking missing values in isbn column 
df1[df1['isbn'].isnull()]
# Out:
#      _id                                          title isbn  pageCount  \
# 21    23          Hibernate in Action (Chinese Edition)  NaN        400
# 98   148                    Portlets and Apache Portals  NaN        500
# 358  707  Secrets of the JavaScript Ninja pBook upgrade  NaN          0
#
#                                  publishedDate  \
# 21   {'$date': '1999-06-01T00:00:00.000-0700'}
# 98   {'$date': '2005-10-01T00:00:00.000-0700'}
# 358                                        NaN
#
#                                           thumbnailUrl  \
# 21   https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 98   https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 358                                                NaN
#
#                                       shortDescription  \
# 21                                                 NaN
# 98   Portlets and Apache Portals was not published ...
# 358                                                NaN
#
# ...

# %%
re.sub('[A-Za-z]*|\n+|-+|,+|:+','',str(df1['isbn']))
# Out:
# '0         19339886731         19351827222         16172900843         19339887464         1935182420           ...      426       1935182455427       1884777856428       1932394524429    1932394524430    1932394524   431  '

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431 entries, 0 to 430
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               431 non-null    object
#  1   title             431 non-null    object
#  2   isbn              428 non-null    object
#  3   pageCount         431 non-null    int64
#  4   publishedDate     353 non-null    object
#  5   thumbnailUrl      411 non-null    object
#  6   shortDescription  160 non-null    object
#  7   longDescription   263 non-null    object
#  8   status            431 non-null    object
#  9   authors           431 non-null    object
#  10  categories        431 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 20.3+ KB

# %%
#rows in the isbn column where the isbn value is null
df1[df1['isbn'].isnull()]
# Out:
#      _id                                          title isbn  pageCount  \
# 21    23          Hibernate in Action (Chinese Edition)  NaN        400
# 98   148                    Portlets and Apache Portals  NaN        500
# 358  707  Secrets of the JavaScript Ninja pBook upgrade  NaN          0
#
#                                  publishedDate  \
# 21   {'$date': '1999-06-01T00:00:00.000-0700'}
# 98   {'$date': '2005-10-01T00:00:00.000-0700'}
# 358                                        NaN
#
#                                           thumbnailUrl  \
# 21   https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 98   https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 358                                                NaN
#
#                                       shortDescription  \
# 21                                                 NaN
# 98   Portlets and Apache Portals was not published ...
# 358                                                NaN
#
# ...

# %%
#dropping the isbn column
df1.drop('isbn',axis = 1,inplace = True)

# %%
df1.head()
# Out:
#   _id                              title  pageCount  \
# 0   1                  Unlocking Android        416
# 1   2  Android in Action, Second Edition        592
# 2   3           Specification by Example          0
# 3   4                   Flex 3 in Action        576
# 4   5                   Flex 4 in Action        600
#
#                                publishedDate  \
# 0  {'$date': '2009-04-01T00:00:00.000-0700'}
# 1  {'$date': '2011-01-14T00:00:00.000-0800'}
# 2  {'$date': '2011-06-03T00:00:00.000-0700'}
# 3  {'$date': '2009-02-02T00:00:00.000-0800'}
# 4  {'$date': '2010-11-15T00:00:00.000-0800'}
#
#                                         thumbnailUrl  \
# 0  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 1  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 2  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 3  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 4  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
#
# ...

# %%
df1.tail()
# Out:
#                                       _id  \
# 426  {'$oid': '53c2ae8528d75d572c06adb8'}
# 427  {'$oid': '53c2ae8528d75d572c06adb9'}
# 428  {'$oid': '53c2ae8528d75d572c06adba'}
# 429  {'$oid': '53c2ae8528d75d572c06adbb'}
# 430  {'$oid': '53c2ae8528d75d572c06adbc'}
#
#                                          title  pageCount  \
# 426                             DSLs in Action        376
# 427  Database Programming for Handheld Devices          0
# 428           Jakarta Commons Online Bookshelf        402
# 429                   Browsing with HttpClient          0
# 430               Codec: Encoders and Decoders          0
#
#                                  publishedDate  \
# 426  {'$date': '2010-12-01T00:00:00.000-0800'}
# 427  {'$date': '2000-07-01T00:00:00.000-0700'}
# 428  {'$date': '2005-03-01T00:00:00.000-0800'}
# 429  {'$date': '2005-03-01T00:00:00.000-0800'}
# 430  {'$date': '2005-03-01T00:00:00.000-0800'}
#
#                                           thumbnailUrl  \
# ...

# %%
# Getting the total number of title ()Unique
len(df1['title'].unique())
# Out:
# 427

# %%
#Duplicated values in title
df1[df1.duplicated('title')]
# Out:
#      _id                                   title  pageCount  \
# 113  165                     Android in Practice          0
# 175  231               SQL Server MVP Deep Dives        848
# 176  232               SQL Server MVP Deep Dives        848
# 325  656  Jaguar Development with PowerBuilder 7          0
#
#                                  publishedDate  \
# 113                                        NaN
# 175  {'$date': '2009-11-15T00:00:00.000-0800'}
# 176  {'$date': '2009-11-01T00:00:00.000-0700'}
# 325  {'$date': '1999-08-09T00:00:00.000-0700'}
#
#                                           thumbnailUrl  \
# 113  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 175  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 176  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 325                                                NaN
#
#                                       shortDescription  \
# 113                                                NaN
# ...

# %%
#drop the duplicated values
df1.drop_duplicates('title',inplace=True)

# %%
df1
# Out:
#                                       _id  \
# 0                                       1
# 1                                       2
# 2                                       3
# 3                                       4
# 4                                       5
# ..                                    ...
# 426  {'$oid': '53c2ae8528d75d572c06adb8'}
# 427  {'$oid': '53c2ae8528d75d572c06adb9'}
# 428  {'$oid': '53c2ae8528d75d572c06adba'}
# 429  {'$oid': '53c2ae8528d75d572c06adbb'}
# 430  {'$oid': '53c2ae8528d75d572c06adbc'}
#
#                                          title  pageCount  \
# 0                            Unlocking Android        416
# 1            Android in Action, Second Edition        592
# 2                     Specification by Example          0
# 3                             Flex 3 in Action        576
# 4                             Flex 4 in Action        600
# ..                                         ...        ...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 427 entries, 0 to 430
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               427 non-null    object
#  1   title             427 non-null    object
#  2   pageCount         427 non-null    int64
#  3   publishedDate     350 non-null    object
#  4   thumbnailUrl      408 non-null    object
#  5   shortDescription  159 non-null    object
#  6   longDescription   262 non-null    object
#  7   status            427 non-null    object
#  8   authors           427 non-null    object
#  9   categories        427 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 21.7+ KB

# %%
df1.shape
# Out:
# (427, 10)

# %%
#Arranging the id column values in ascending order starting from 1
df1['_id']=np.arange(1,428)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 427 entries, 0 to 430
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               427 non-null    int32
#  1   title             427 non-null    object
#  2   pageCount         427 non-null    int64
#  3   publishedDate     350 non-null    object
#  4   thumbnailUrl      408 non-null    object
#  5   shortDescription  159 non-null    object
#  6   longDescription   262 non-null    object
#  7   status            427 non-null    object
#  8   authors           427 non-null    object
#  9   categories        427 non-null    object
# dtypes: int32(1), int64(1), object(8)
# memory usage: 21.7+ KB

# %%
# Reindexing
df1 = df1.reset_index(drop=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 427 entries, 0 to 426
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               427 non-null    int32
#  1   title             427 non-null    object
#  2   pageCount         427 non-null    int64
#  3   publishedDate     350 non-null    object
#  4   thumbnailUrl      408 non-null    object
#  5   shortDescription  159 non-null    object
#  6   longDescription   262 non-null    object
#  7   status            427 non-null    object
#  8   authors           427 non-null    object
#  9   categories        427 non-null    object
# dtypes: int32(1), int64(1), object(8)
# memory usage: 18.4+ KB

# %%
df1.tail()
# Out:
#      _id                                      title  pageCount  \
# 422  423                             DSLs in Action        376
# 423  424  Database Programming for Handheld Devices          0
# 424  425           Jakarta Commons Online Bookshelf        402
# 425  426                   Browsing with HttpClient          0
# 426  427               Codec: Encoders and Decoders          0
#
#                                  publishedDate  \
# 422  {'$date': '2010-12-01T00:00:00.000-0800'}
# 423  {'$date': '2000-07-01T00:00:00.000-0700'}
# 424  {'$date': '2005-03-01T00:00:00.000-0800'}
# 425  {'$date': '2005-03-01T00:00:00.000-0800'}
# 426  {'$date': '2005-03-01T00:00:00.000-0800'}
#
#                                           thumbnailUrl  \
# 422  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 423  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 424  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 425  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# ...

# %%
# Replacing the values in the pageCount column where the value == 0 
#with the mean of the pageCount column elements

df1['pageCount'].replace (0,round((np.mean(df1['pageCount']))))
# Out:
# 0      416
# 1      592
# 2      288
# 3      576
# 4      600
#       ...
# 422    376
# 423    288
# 424    402
# 425    288
# 426    288
# Name: pageCount, Length: 427, dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 427 entries, 0 to 426
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               427 non-null    int32
#  1   title             427 non-null    object
#  2   pageCount         427 non-null    int64
#  3   publishedDate     350 non-null    object
#  4   thumbnailUrl      408 non-null    object
#  5   shortDescription  159 non-null    object
#  6   longDescription   262 non-null    object
#  7   status            427 non-null    object
#  8   authors           427 non-null    object
#  9   categories        427 non-null    object
# dtypes: int32(1), int64(1), object(8)
# memory usage: 18.4+ KB

# %%
#Creating copy of DataFrame df1 
data = df1.copy()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 427 entries, 0 to 426
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               427 non-null    int32
#  1   title             427 non-null    object
#  2   pageCount         427 non-null    int64
#  3   publishedDate     350 non-null    object
#  4   thumbnailUrl      408 non-null    object
#  5   shortDescription  159 non-null    object
#  6   longDescription   262 non-null    object
#  7   status            427 non-null    object
#  8   authors           427 non-null    object
#  9   categories        427 non-null    object
# dtypes: int32(1), int64(1), object(8)
# memory usage: 18.4+ KB

# %%
data=data.rename(columns={'publishedDate':'publishedYear'})

# %%
data
# Out:
#      _id                                      title  pageCount  \
# 0      1                          Unlocking Android        416
# 1      2          Android in Action, Second Edition        592
# 2      3                   Specification by Example          0
# 3      4                           Flex 3 in Action        576
# 4      5                           Flex 4 in Action        600
# ..   ...                                        ...        ...
# 422  423                             DSLs in Action        376
# 423  424  Database Programming for Handheld Devices          0
# 424  425           Jakarta Commons Online Bookshelf        402
# 425  426                   Browsing with HttpClient          0
# 426  427               Codec: Encoders and Decoders          0
#
#                                  publishedYear  \
# 0    {'$date': '2009-04-01T00:00:00.000-0700'}
# 1    {'$date': '2011-01-14T00:00:00.000-0800'}
# 2    {'$date': '2011-06-03T00:00:00.000-0700'}
# ...

# %%
#Getting only year value from publishedYear using regular expression
for i in range(len(data.publishedYear)):
    data.publishedYear[i] = re.sub("^{.* '|-.*}","",str(data['publishedYear'][i]))

data
# Out:
# <ipython-input-52-a207b7ef07c8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.publishedYear[i] = re.sub("^{.* '|-.*}","",str(data['publishedYear'][i]))
#      _id                                      title  pageCount publishedYear  \
# 0      1                          Unlocking Android        416          2009
# 1      2          Android in Action, Second Edition        592          2011
# 2      3                   Specification by Example          0          2011
# 3      4                           Flex 3 in Action        576          2009
# 4      5                           Flex 4 in Action        600          2010
# ..   ...                                        ...        ...           ...
# 422  423                             DSLs in Action        376          2010
# ...

# %%
#Filling the NaN with 0
data['publishedYear'].fillna("0",inplace=True)

# %%
data.head()
# Out:
#    _id                              title  pageCount publishedYear  \
# 0    1                  Unlocking Android        416          2009
# 1    2  Android in Action, Second Edition        592          2011
# 2    3           Specification by Example          0          2011
# 3    4                   Flex 3 in Action        576          2009
# 4    5                   Flex 4 in Action        600          2010
#
#                                         thumbnailUrl  \
# 0  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 1  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 2  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 3  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 4  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
#
#                                     shortDescription  \
# 0  Unlocking Android: A Developer's Guide provide...
# 1  Android in Action, Second Edition is a compreh...
# 2                                                NaN
# ...

# %%
data.loc[[96]]
# Out:
#     _id                        title  pageCount publishedYear  \
# 96   97  Distributed Agile in Action        325           nan
#
#                                          thumbnailUrl  \
# 96  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
#
#                                      shortDescription  \
# 96  Distributed Agile in Action is the first book ...
#
#                                       longDescription status  \
# 96  As organizations try to do more with less, dev...   MEAP
#
#                                  authors              categories
# 96  [Vikas Hazrati, Balaji D Loganathan]  [Software Engineering]

# %%
#Replacing nan value with 0 in publishedYear
data.publishedYear = data.publishedYear.replace('nan','0')

# %%
data.publishedYear
# Out:
# 0      2009
# 1      2011
# 2      2011
# 3      2009
# 4      2010
#        ...
# 422    2010
# 423    2000
# 424    2005
# 425    2005
# 426    2005
# Name: publishedYear, Length: 427, dtype: object

# %%
#Converting datatype of publishedYear from object to int
data.publishedYear = data.publishedYear.astype(int)

# %%
data.publishedYear
# Out:
# 0      2009
# 1      2011
# 2      2011
# 3      2009
# 4      2010
#        ...
# 422    2010
# 423    2000
# 424    2005
# 425    2005
# 426    2005
# Name: publishedYear, Length: 427, dtype: int32

# %%
#Replacing 0 with mean of publishedYear column element in publishedYear column  
data['publishedYear']=data['publishedYear'].replace(0,round(np.mean(data['publishedYear'])))

# %%
data['publishedYear']
# Out:
# 0      2009
# 1      2011
# 2      2011
# 3      2009
# 4      2010
#        ...
# 422    2010
# 423    2000
# 424    2005
# 425    2005
# 426    2005
# Name: publishedYear, Length: 427, dtype: int32

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 427 entries, 0 to 426
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               427 non-null    int32
#  1   title             427 non-null    object
#  2   pageCount         427 non-null    int64
#  3   publishedYear     427 non-null    int32
#  4   thumbnailUrl      408 non-null    object
#  5   shortDescription  159 non-null    object
#  6   longDescription   262 non-null    object
#  7   status            427 non-null    object
#  8   authors           427 non-null    object
#  9   categories        427 non-null    object
# dtypes: int32(2), int64(1), object(7)
# memory usage: 18.4+ KB

# %%
#Dropping columns thumbnailUrl,shortDescription,longDescription
data.drop(['thumbnailUrl','shortDescription','longDescription'],axis = 1,inplace = True)

# %%
#Unique values from status column
data.status.unique()
# Out:
# array(['PUBLISH', 'MEAP'], dtype=object)

# %%
#Finding the number of books with PUBLISH and UNPUBLISH status
data['status'].value_counts()
# Out:
# PUBLISH    360
# MEAP        67
# Name: status, dtype: int64

# %%
# Replacing the MEAP to UNPUBLISH
data['status']=data['status'].replace('MEAP','UNPUBLISH')

# %%
#Number of PUBLISH and UNPUBLISH status in status column
data['status'].value_counts()
# Out:
# PUBLISH      360
# UNPUBLISH     67
# Name: status, dtype: int64

# %%
data.authors
# Out:
# 0          [W. Frank Ableson, Charlie Collins, Robi Sen]
# 1                           [W. Frank Ableson, Robi Sen]
# 2                                          [Gojko Adzic]
# 3            [Tariq Ahmed with Jon Hirschi, Faisal Abid]
# 4      [Tariq Ahmed, Dan Orlando, John C. Bland II, J...
#                              ...
# 422                                                   []
# 423                                                   []
# 424                                                   []
# 425                                                   []
# 426                                                   []
# Name: authors, Length: 427, dtype: object

# %%
#Counting empty lists present in authors columns
x=[i for i in data.authors if(i==[])]
len(x)
# Out:
# 37

# %%
data
# Out:
#      _id                                      title  pageCount  publishedYear  \
# 0      1                          Unlocking Android        416           2009
# 1      2          Android in Action, Second Edition        592           2011
# 2      3                   Specification by Example          0           2011
# 3      4                           Flex 3 in Action        576           2009
# 4      5                           Flex 4 in Action        600           2010
# ..   ...                                        ...        ...            ...
# 422  423                             DSLs in Action        376           2010
# 423  424  Database Programming for Handheld Devices          0           2000
# 424  425           Jakarta Commons Online Bookshelf        402           2005
# 425  426                   Browsing with HttpClient          0           2005
# 426  427               Codec: Encoders and Decoders          0           2005
#
# ...

# %%
#Dropping columns _id,authors,categories from DataFrame
data.drop(['_id','authors','categories'],axis = 1,inplace = True)

# %%
data
# Out:
#                                          title  pageCount  publishedYear  \
# 0                            Unlocking Android        416           2009
# 1            Android in Action, Second Edition        592           2011
# 2                     Specification by Example          0           2011
# 3                             Flex 3 in Action        576           2009
# 4                             Flex 4 in Action        600           2010
# ..                                         ...        ...            ...
# 422                             DSLs in Action        376           2010
# 423  Database Programming for Handheld Devices          0           2000
# 424           Jakarta Commons Online Bookshelf        402           2005
# 425                   Browsing with HttpClient          0           2005
# 426               Codec: Encoders and Decoders          0           2005
#
#       status
# 0    PUBLISH
# 1    PUBLISH
# 2    PUBLISH
# 3    PUBLISH
# 4    PUBLISH
# ...

# %% [markdown]
# # Data Analysis

# %%
data.head()
# Out:
#                                title  pageCount  publishedYear   status
# 0                  Unlocking Android        416           2009  PUBLISH
# 1  Android in Action, Second Edition        592           2011  PUBLISH
# 2           Specification by Example          0           2011  PUBLISH
# 3                   Flex 3 in Action        576           2009  PUBLISH
# 4                   Flex 4 in Action        600           2010  PUBLISH

# %%
#count of categories of status column
data['status'].value_counts().plot.bar(figsize=(10,9))
plt.grid()

# %%
# From above bar graph we conclude that the books with PUBLISH status ismore than 
#UNPUBLISH status

# %%
#Finding the number of books published in particular year 
data['publishedYear'].value_counts()
# Out:
# 1645    77
# 2011    38
# 2012    31
# 2013    31
# 2009    25
# 2005    23
# 2002    23
# 2010    21
# 2008    19
# 2014    16
# 2003    15
# 2007    14
# 1999    13
# 2004    13
# 1997    13
# 1998    12
# 2006    11
# 2000    10
# 1996     9
# 1995     7
# 2001     5
# 1993     1
# Name: publishedYear, dtype: int64

# %%
plt.hist(data['publishedYear'],range=(1600,2100),bins=5)
plt.title('Published Year V/S Number of books published')
plt.xlabel('Published Year')
plt.ylabel('Number of books published')
plt.show()

# %%
#Above graph shows the number of books published in between years
#1600-1700
#1700-1800
#1800-1900
#1900-2000
#2000-2100

# %%
data['publishedYear']
# Out:
# 0      2009
# 1      2011
# 2      2011
# 3      2009
# 4      2010
#        ...
# 422    2010
# 423    2000
# 424    2005
# 425    2005
# 426    2005
# Name: publishedYear, Length: 427, dtype: int32

# %%
data
# Out:
#                                          title  pageCount  publishedYear  \
# 0                            Unlocking Android        416           2009
# 1            Android in Action, Second Edition        592           2011
# 2                     Specification by Example          0           2011
# 3                             Flex 3 in Action        576           2009
# 4                             Flex 4 in Action        600           2010
# ..                                         ...        ...            ...
# 422                             DSLs in Action        376           2010
# 423  Database Programming for Handheld Devices          0           2000
# 424           Jakarta Commons Online Bookshelf        402           2005
# 425                   Browsing with HttpClient          0           2005
# 426               Codec: Encoders and Decoders          0           2005
#
#       status
# 0    PUBLISH
# 1    PUBLISH
# 2    PUBLISH
# 3    PUBLISH
# 4    PUBLISH
# ...

# %%
#Top 10 books with more number of pages
x=data.sort_values('pageCount',ascending=False).head(10)
x
# Out:
#                                                  title  pageCount  \
# 60   Essential Guide to Peoplesoft Development and ...       1101
# 251                      Ten Years of UserFriendly.Org       1096
# 68                             Java Foundation Classes       1088
# 397                            Windows Forms in Action        950
# 189                            Silverlight 5 in Action        925
# 211                               Swing Second Edition        912
# 408                Dynamic WAP Application Development        888
# 22                     Java Persistence with Hibernate        880
# 102           Java Network Programming, Second Edition        860
# 173                          SQL Server MVP Deep Dives        848
#
#      publishedYear   status
# 60            2000  PUBLISH
# 251           2008  PUBLISH
# 68            2001  PUBLISH
# 397           2006  PUBLISH
# 189           2012  PUBLISH
# 211           2003  PUBLISH
# 408           2002  PUBLISH
# ...

# %%
data.head()
# Out:
#                                title  pageCount  publishedYear   status
# 0                  Unlocking Android        416           2009  PUBLISH
# 1  Android in Action, Second Edition        592           2011  PUBLISH
# 2           Specification by Example          0           2011  PUBLISH
# 3                   Flex 3 in Action        576           2009  PUBLISH
# 4                   Flex 4 in Action        600           2010  PUBLISH

# %%
plt.figure(figsize=(16,9))
plt.bar(x['title'],x['pageCount'])
plt.title('Title of book V/S pageCount of book')
plt.xlabel('Title of book')
plt.ylabel('Pagecount of book')
plt.show()

# %%
#The above graph shows top 10 books with their pagecount
